# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from citipy import citipy

#Import the OpenWeather key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats, lngs)
coordinates

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# Define the static parameters for the request
OW_key = weather_api_key
OW_units = "imperial"

# Define the base url
OW_url = "https://api.openweathermap.org/data/2.5/weather?q="

# The url should look like this:
# https://api.openweathermap.org/data/2.5/weather?q={city name}&units={Units}&appid={API key}

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("--------------------------------")
print("    Beginning Data Retrieval    ")
print("--------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Change spaces for plus signs to avoid url errors
    OW_city = city.replace(" ","+")
    
    # Create endpoint URL with each city.
    city_url = f"{OW_url}{OW_city}&units={OW_units}&appid={OW_key}"
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except Exception as e:
        
        print(f"Error for while looking for information on {city} at entry {50 * (set_count - 1 ) + record_count - 1}")
        print(f"Received the following error: {e}")
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("---------------------------------")
print("    Data Retrieval Complete      ")
print("---------------------------------")
# Out:
# --------------------------------
#     Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | barbacoas
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | barra patuca
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | caravelas
# Processing Record 10 of Set 1 | clyde river
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | srem
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | awjilah
# Processing Record 17 of Set 1 | hasaki
# Processing Record 18 of Set 1 | jiuquan
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | davidson
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | illoqqortoormiut
# Error for while looking for information on illoqqortoormiut at entry 22
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 1 | taolanaro
# Error for while looking for information on taolanaro at entry 23
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | tumannyy
# Error for while looking for information on tumannyy at entry 25
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | palabuhanratu
# Error for while looking for information on palabuhanratu at entry 29
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 1 | boksitogorsk
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | faanui
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | portland
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | ottumwa
# Processing Record 39 of Set 1 | mogzon
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | shingu
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | lulea
# Processing Record 44 of Set 1 | antalaha
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | saleaula
# Error for while looking for information on saleaula at entry 47
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 1 | itoman
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | homer
# Processing Record 2 of Set 2 | mount gambier
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | phangnga
# Processing Record 6 of Set 2 | nizhneyansk
# Error for while looking for information on nizhneyansk at entry 56
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | luebo
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | cochrane
# Processing Record 11 of Set 2 | buarcos
# Processing Record 12 of Set 2 | tete
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | ayorou
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | springbok
# Processing Record 18 of Set 2 | tual
# Processing Record 19 of Set 2 | tonantins
# Processing Record 20 of Set 2 | kruisfontein
# Processing Record 21 of Set 2 | atar
# Processing Record 22 of Set 2 | klaksvik
# Processing Record 23 of Set 2 | angoche
# Processing Record 24 of Set 2 | grindavik
# Processing Record 25 of Set 2 | lompoc
# Processing Record 26 of Set 2 | guerrero negro
# Processing Record 27 of Set 2 | san rafael del sur
# Processing Record 28 of Set 2 | belushya guba
# Error for while looking for information on belushya guba at entry 78
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 2 | saint-joseph
# Processing Record 30 of Set 2 | leningradskiy
# Processing Record 31 of Set 2 | kawalu
# Processing Record 32 of Set 2 | phumi samraong
# Error for while looking for information on phumi samraong at entry 82
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 2 | dubrovytsya
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | nouadhibou
# Processing Record 36 of Set 2 | zwedru
# Processing Record 37 of Set 2 | bilma
# Processing Record 38 of Set 2 | la ronge
# Processing Record 39 of Set 2 | lat yao
# Processing Record 40 of Set 2 | rocha
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | airai
# Processing Record 43 of Set 2 | sulangan
# Processing Record 44 of Set 2 | murgab
# Processing Record 45 of Set 2 | harwich
# Processing Record 46 of Set 2 | mabaruma
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | mataura
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | vila velha
# Processing Record 3 of Set 3 | ostrovnoy
# Processing Record 4 of Set 3 | port lincoln
# Processing Record 5 of Set 3 | hamilton
# Processing Record 6 of Set 3 | cap-chat
# Processing Record 7 of Set 3 | olinda
# Processing Record 8 of Set 3 | zhigansk
# Processing Record 9 of Set 3 | santa maria
# Processing Record 10 of Set 3 | grobina
# Processing Record 11 of Set 3 | naze
# Processing Record 12 of Set 3 | battle creek
# Processing Record 13 of Set 3 | divnoye
# Processing Record 14 of Set 3 | tuatapere
# Processing Record 15 of Set 3 | ambilobe
# Processing Record 16 of Set 3 | ardistan
# Error for while looking for information on ardistan at entry 116
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 3 | buchanan
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | san quintin
# Processing Record 20 of Set 3 | atasu
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | lugus
# Processing Record 23 of Set 3 | nogliki
# Processing Record 24 of Set 3 | bubaque
# Processing Record 25 of Set 3 | mazamari
# Processing Record 26 of Set 3 | new london
# Processing Record 27 of Set 3 | ancud
# Processing Record 28 of Set 3 | smithfield
# Processing Record 29 of Set 3 | malinovoye ozero
# Processing Record 30 of Set 3 | astipalaia
# Error for while looking for information on astipalaia at entry 130
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 3 | kieta
# Processing Record 32 of Set 3 | verkhoyansk
# Processing Record 33 of Set 3 | lavrentiya
# Processing Record 34 of Set 3 | mergui
# Error for while looking for information on mergui at entry 134
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 3 | new norfolk
# Processing Record 36 of Set 3 | tebingtinggi
# Processing Record 37 of Set 3 | asau
# Processing Record 38 of Set 3 | lardos
# Processing Record 39 of Set 3 | nianzishan
# Processing Record 40 of Set 3 | inirida
# Processing Record 41 of Set 3 | mount pleasant
# Processing Record 42 of Set 3 | oron
# Processing Record 43 of Set 3 | clifton
# Processing Record 44 of Set 3 | alofi
# Processing Record 45 of Set 3 | charlottesville
# Processing Record 46 of Set 3 | zonguldak
# Processing Record 47 of Set 3 | gorontalo
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | halifax
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | ulladulla
# Processing Record 3 of Set 4 | mareeba
# Processing Record 4 of Set 4 | kalanwali
# Processing Record 5 of Set 4 | saint-francois
# Processing Record 6 of Set 4 | maniitsoq
# Processing Record 7 of Set 4 | san cristobal
# Processing Record 8 of Set 4 | sunyani
# Processing Record 9 of Set 4 | sao joao da barra
# Processing Record 10 of Set 4 | vaasa
# Processing Record 11 of Set 4 | takoradi
# Processing Record 12 of Set 4 | bogovarovo
# Processing Record 13 of Set 4 | gerash
# Processing Record 14 of Set 4 | cabatuan
# Processing Record 15 of Set 4 | katsuura
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | samalaeulu
# Error for while looking for information on samalaeulu at entry 167
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 4 | hofn
# Processing Record 19 of Set 4 | iqaluit
# Processing Record 20 of Set 4 | vestmannaeyjar
# Processing Record 21 of Set 4 | sentyabrskiy
# Error for while looking for information on sentyabrskiy at entry 171
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 4 | coahuayana
# Processing Record 23 of Set 4 | wanganui
# Processing Record 24 of Set 4 | rudbar
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | lata
# Processing Record 27 of Set 4 | vila franca do campo
# Processing Record 28 of Set 4 | jalu
# Processing Record 29 of Set 4 | merauke
# Processing Record 30 of Set 4 | sitka
# Processing Record 31 of Set 4 | honavar
# Processing Record 32 of Set 4 | yulara
# Processing Record 33 of Set 4 | boa vista
# Processing Record 34 of Set 4 | tautira
# Processing Record 35 of Set 4 | walvis bay
# Processing Record 36 of Set 4 | torbay
# Processing Record 37 of Set 4 | shizunai
# Processing Record 38 of Set 4 | haines junction
# Processing Record 39 of Set 4 | bambous virieux
# Processing Record 40 of Set 4 | rock springs
# Processing Record 41 of Set 4 | los llanos de aridane
# Processing Record 42 of Set 4 | saint-augustin
# Processing Record 43 of Set 4 | west odessa
# Processing Record 44 of Set 4 | thompson
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | vasterhaninge
# Processing Record 47 of Set 4 | muyezerskiy
# Processing Record 48 of Set 4 | taoudenni
# Processing Record 49 of Set 4 | warqla
# Error for while looking for information on warqla at entry 199
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 4 | amderma
# Error for while looking for information on amderma at entry 200
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 5 | aksarka
# Processing Record 2 of Set 5 | juneau
# Processing Record 3 of Set 5 | mount isa
# Processing Record 4 of Set 5 | faranah
# Processing Record 5 of Set 5 | hobyo
# Processing Record 6 of Set 5 | chuy
# Processing Record 7 of Set 5 | barentsburg
# Error for while looking for information on barentsburg at entry 207
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 5 | avarua
# Processing Record 9 of Set 5 | geraldton
# Processing Record 10 of Set 5 | kahului
# Processing Record 11 of Set 5 | talcahuano
# Processing Record 12 of Set 5 | nurota
# Processing Record 13 of Set 5 | ukiah
# Processing Record 14 of Set 5 | henties bay
# Processing Record 15 of Set 5 | north bend
# Processing Record 16 of Set 5 | leshukonskoye
# Processing Record 17 of Set 5 | northam
# Processing Record 18 of Set 5 | cassilandia
# Processing Record 19 of Set 5 | huicheng
# Processing Record 20 of Set 5 | mnogovershinnyy
# Processing Record 21 of Set 5 | port macquarie
# Processing Record 22 of Set 5 | samusu
# Error for while looking for information on samusu at entry 222
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 5 | colchester
# Processing Record 24 of Set 5 | dariba
# Processing Record 25 of Set 5 | pangnirtung
# Processing Record 26 of Set 5 | ranau
# Processing Record 27 of Set 5 | nhulunbuy
# Processing Record 28 of Set 5 | isangel
# Processing Record 29 of Set 5 | marawi
# Processing Record 30 of Set 5 | filadelfia
# Processing Record 31 of Set 5 | cockburn town
# Processing Record 32 of Set 5 | basco
# Processing Record 33 of Set 5 | muros
# Processing Record 34 of Set 5 | tadine
# Processing Record 35 of Set 5 | damietta
# Processing Record 36 of Set 5 | narsaq
# Processing Record 37 of Set 5 | frolovo
# Processing Record 38 of Set 5 | msowero
# Processing Record 39 of Set 5 | port-cartier
# Processing Record 40 of Set 5 | bronnoysund
# Processing Record 41 of Set 5 | alberton
# Processing Record 42 of Set 5 | coquimbo
# Processing Record 43 of Set 5 | sao felix do xingu
# Processing Record 44 of Set 5 | calabozo
# Processing Record 45 of Set 5 | husavik
# Processing Record 46 of Set 5 | puerto del rosario
# Processing Record 47 of Set 5 | chipinge
# Processing Record 48 of Set 5 | dinga
# Processing Record 49 of Set 5 | saldanha
# Processing Record 50 of Set 5 | maneadero
# Processing Record 1 of Set 6 | luderitz
# Processing Record 2 of Set 6 | anta
# Processing Record 3 of Set 6 | upata
# Processing Record 4 of Set 6 | cabo san lucas
# Processing Record 5 of Set 6 | touros
# Processing Record 6 of Set 6 | yangambi
# Processing Record 7 of Set 6 | xuddur
# Processing Record 8 of Set 6 | dunedin
# Processing Record 9 of Set 6 | karratha
# Processing Record 10 of Set 6 | bajil
# Processing Record 11 of Set 6 | ruatoria
# Error for while looking for information on ruatoria at entry 261
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 6 | okhotsk
# Processing Record 13 of Set 6 | norman wells
# Processing Record 14 of Set 6 | san blas
# Processing Record 15 of Set 6 | kutum
# Processing Record 16 of Set 6 | poum
# Processing Record 17 of Set 6 | dingle
# Processing Record 18 of Set 6 | nyurba
# Processing Record 19 of Set 6 | logan lake
# Processing Record 20 of Set 6 | ingham
# Processing Record 21 of Set 6 | barawe
# Error for while looking for information on barawe at entry 271
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 6 | ouallam
# Processing Record 23 of Set 6 | saskylakh
# Processing Record 24 of Set 6 | nanortalik
# Processing Record 25 of Set 6 | alpena
# Processing Record 26 of Set 6 | mastic beach
# Processing Record 27 of Set 6 | vao
# Processing Record 28 of Set 6 | plessisville
# Processing Record 29 of Set 6 | mantua
# Processing Record 30 of Set 6 | ibra
# Processing Record 31 of Set 6 | lingyuan
# Processing Record 32 of Set 6 | esperance
# Processing Record 33 of Set 6 | saint-pierre
# Processing Record 34 of Set 6 | ust-nera
# Processing Record 35 of Set 6 | victor harbor
# Processing Record 36 of Set 6 | pevek
# Processing Record 37 of Set 6 | maldonado
# Processing Record 38 of Set 6 | constitucion
# Processing Record 39 of Set 6 | kota kinabalu
# Processing Record 40 of Set 6 | hunza
# Error for while looking for information on hunza at entry 290
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 6 | george
# Processing Record 42 of Set 6 | grand river south east
# Error for while looking for information on grand river south east at entry 292
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 6 | aitape
# Processing Record 44 of Set 6 | lisa
# Processing Record 45 of Set 6 | temir
# Processing Record 46 of Set 6 | redwater
# Processing Record 47 of Set 6 | brod
# Processing Record 48 of Set 6 | zhaotong
# Processing Record 49 of Set 6 | kuche
# Error for while looking for information on kuche at entry 299
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 6 | pozo colorado
# Processing Record 1 of Set 7 | umba
# Processing Record 2 of Set 7 | tsihombe
# Error for while looking for information on tsihombe at entry 302
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 7 | mizdah
# Processing Record 4 of Set 7 | petrykivka
# Processing Record 5 of Set 7 | akdepe
# Processing Record 6 of Set 7 | portree
# Processing Record 7 of Set 7 | mecca
# Processing Record 8 of Set 7 | odweyne
# Processing Record 9 of Set 7 | partizanskoye
# Processing Record 10 of Set 7 | cidreira
# Processing Record 11 of Set 7 | karauzyak
# Error for while looking for information on karauzyak at entry 311
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 7 | nikolskoye-na-cheremshane
# Error for while looking for information on nikolskoye-na-cheremshane at entry 312
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 7 | plettenberg bay
# Processing Record 14 of Set 7 | attawapiskat
# Error for while looking for information on attawapiskat at entry 314
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 7 | sunrise manor
# Processing Record 16 of Set 7 | tura
# Processing Record 17 of Set 7 | leeton
# Processing Record 18 of Set 7 | kuytun
# Processing Record 19 of Set 7 | marovoay
# Processing Record 20 of Set 7 | rorvik
# Processing Record 21 of Set 7 | faya
# Processing Record 22 of Set 7 | sarny
# Processing Record 23 of Set 7 | kukshi
# Processing Record 24 of Set 7 | moerai
# Processing Record 25 of Set 7 | ravar
# Processing Record 26 of Set 7 | bryan
# Processing Record 27 of Set 7 | butaritari
# Processing Record 28 of Set 7 | naziya
# Processing Record 29 of Set 7 | chaozhou
# Processing Record 30 of Set 7 | auki
# Processing Record 31 of Set 7 | mayumba
# Processing Record 32 of Set 7 | mayo
# Processing Record 33 of Set 7 | shimoda
# Processing Record 34 of Set 7 | salalah
# Processing Record 35 of Set 7 | whitecourt
# Processing Record 36 of Set 7 | pilar
# Processing Record 37 of Set 7 | myaundzha
# Processing Record 38 of Set 7 | margate
# Processing Record 39 of Set 7 | raton
# Processing Record 40 of Set 7 | kawana waters
# Error for while looking for information on kawana waters at entry 340
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 7 | ahipara
# Processing Record 42 of Set 7 | kukes
# Processing Record 43 of Set 7 | monroe
# Processing Record 44 of Set 7 | padang
# Processing Record 45 of Set 7 | dodan
# Processing Record 46 of Set 7 | safaga
# Processing Record 47 of Set 7 | kununurra
# Processing Record 48 of Set 7 | port hardy
# Processing Record 49 of Set 7 | bacalar
# Processing Record 50 of Set 7 | vrangel
# Processing Record 1 of Set 8 | gat
# Processing Record 2 of Set 8 | olafsvik
# Processing Record 3 of Set 8 | longyearbyen
# Processing Record 4 of Set 8 | san jose
# Processing Record 5 of Set 8 | itarema
# Processing Record 6 of Set 8 | emerald
# Processing Record 7 of Set 8 | the valley
# Processing Record 8 of Set 8 | acapulco
# Processing Record 9 of Set 8 | ribeira grande
# Processing Record 10 of Set 8 | bayangol
# Processing Record 11 of Set 8 | vardo
# Processing Record 12 of Set 8 | vaitupu
# Error for while looking for information on vaitupu at entry 362
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 8 | santa vitoria do palmar
# Processing Record 14 of Set 8 | tirschenreuth
# Processing Record 15 of Set 8 | saint-georges
# Processing Record 16 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 8 | anadyr
# Processing Record 18 of Set 8 | angoram
# Processing Record 19 of Set 8 | providencia
# Processing Record 20 of Set 8 | severo-kurilsk
# Processing Record 21 of Set 8 | utiroa
# Error for while looking for information on utiroa at entry 371
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 8 | mys shmidta
# Error for while looking for information on mys shmidta at entry 372
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 8 | udachnyy
# Processing Record 24 of Set 8 | scarborough
# Processing Record 25 of Set 8 | ereymentau
# Processing Record 26 of Set 8 | angol
# Processing Record 27 of Set 8 | mandla
# Processing Record 28 of Set 8 | loandjili
# Processing Record 29 of Set 8 | porosozero
# Processing Record 30 of Set 8 | beringovskiy
# Processing Record 31 of Set 8 | nemuro
# Processing Record 32 of Set 8 | steamboat springs
# Processing Record 33 of Set 8 | valparaiso
# Processing Record 34 of Set 8 | paamiut
# Processing Record 35 of Set 8 | killybegs
# Processing Record 36 of Set 8 | mahebourg
# Processing Record 37 of Set 8 | najran
# Processing Record 38 of Set 8 | sal rei
# Processing Record 39 of Set 8 | irbit
# Processing Record 40 of Set 8 | belaya gora
# Processing Record 41 of Set 8 | axim
# Processing Record 42 of Set 8 | acari
# Processing Record 43 of Set 8 | maningrida
# Processing Record 44 of Set 8 | viedma
# Processing Record 45 of Set 8 | kisangani
# Processing Record 46 of Set 8 | porto novo
# Processing Record 47 of Set 8 | mumford
# Processing Record 48 of Set 8 | tizapan el alto
# Processing Record 49 of Set 8 | srednekolymsk
# Processing Record 50 of Set 8 | cravo norte
# Processing Record 1 of Set 9 | okandja
# Error for while looking for information on okandja at entry 401
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 9 | kamenka
# Processing Record 3 of Set 9 | hoima
# Processing Record 4 of Set 9 | inuvik
# Processing Record 5 of Set 9 | menongue
# Processing Record 6 of Set 9 | catamarca
# Processing Record 7 of Set 9 | ipixuna
# Processing Record 8 of Set 9 | mons
# Processing Record 9 of Set 9 | kavieng
# Processing Record 10 of Set 9 | wajima
# Processing Record 11 of Set 9 | guaratinga
# Processing Record 12 of Set 9 | novaya lyalya
# Processing Record 13 of Set 9 | kamenskoye
# Error for while looking for information on kamenskoye at entry 413
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 9 | trebisacce
# Processing Record 15 of Set 9 | carballo
# Processing Record 16 of Set 9 | uvelskiy
# Processing Record 17 of Set 9 | santa rosa
# Processing Record 18 of Set 9 | severomuysk
# Processing Record 19 of Set 9 | fredericton
# Processing Record 20 of Set 9 | deputatskiy
# Processing Record 21 of Set 9 | quelimane
# Processing Record 22 of Set 9 | erzin
# Processing Record 23 of Set 9 | port hedland
# Processing Record 24 of Set 9 | berdigestyakh
# Processing Record 25 of Set 9 | yenagoa
# Processing Record 26 of Set 9 | collie
# Processing Record 27 of Set 9 | roccastrada
# Processing Record 28 of Set 9 | asfi
# Processing Record 29 of Set 9 | biak
# Processing Record 30 of Set 9 | visby
# Processing Record 31 of Set 9 | karkaralinsk
# Error for while looking for information on karkaralinsk at entry 431
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 9 | evensk
# Processing Record 33 of Set 9 | ilulissat
# Processing Record 34 of Set 9 | naryan-mar
# Processing Record 35 of Set 9 | broome
# Processing Record 36 of Set 9 | cabedelo
# Processing Record 37 of Set 9 | fortuna
# Processing Record 38 of Set 9 | kangasala
# Processing Record 39 of Set 9 | yar-sale
# Processing Record 40 of Set 9 | brae
# Processing Record 41 of Set 9 | horsham
# Processing Record 42 of Set 9 | harper
# Processing Record 43 of Set 9 | souillac
# Processing Record 44 of Set 9 | la palma
# Processing Record 45 of Set 9 | kushiro
# Processing Record 46 of Set 9 | kochubey
# Processing Record 47 of Set 9 | galesong
# Processing Record 48 of Set 9 | wajid
# Processing Record 49 of Set 9 | shelbyville
# Processing Record 50 of Set 9 | talnakh
# Processing Record 1 of Set 10 | vedaranniyam
# Error for while looking for information on vedaranniyam at entry 451
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 10 | kimbe
# Processing Record 3 of Set 10 | semporna
# Processing Record 4 of Set 10 | louisbourg
# Error for while looking for information on louisbourg at entry 454
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 10 | half moon bay
# Processing Record 6 of Set 10 | ponta delgada
# Processing Record 7 of Set 10 | pinawa
# Processing Record 8 of Set 10 | storforshei
# Processing Record 9 of Set 10 | sumbawa
# Error for while looking for information on sumbawa at entry 459
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 10 | sri aman
# Processing Record 11 of Set 10 | sheridan
# Processing Record 12 of Set 10 | rambha
# Processing Record 13 of Set 10 | norwich
# Processing Record 14 of Set 10 | mozarlandia
# Processing Record 15 of Set 10 | bellevue
# Processing Record 16 of Set 10 | saint combs
# Error for while looking for information on saint combs at entry 466
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 10 | bairiki
# Processing Record 18 of Set 10 | laguna
# Processing Record 19 of Set 10 | banska bystrica
# Processing Record 20 of Set 10 | labuhan
# Processing Record 21 of Set 10 | santa cruz
# Processing Record 22 of Set 10 | tanete
# Processing Record 23 of Set 10 | nara
# Processing Record 24 of Set 10 | flinders
# Processing Record 25 of Set 10 | namatanai
# Processing Record 26 of Set 10 | nabire
# Processing Record 27 of Set 10 | ozernovskiy
# Processing Record 28 of Set 10 | rucheng
# Processing Record 29 of Set 10 | lagoa
# Processing Record 30 of Set 10 | xining
# Processing Record 31 of Set 10 | kokkola
# Processing Record 32 of Set 10 | mamlyutka
# Processing Record 33 of Set 10 | huarmey
# Processing Record 34 of Set 10 | karaul
# Error for while looking for information on karaul at entry 484
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 10 | cayenne
# Processing Record 36 of Set 10 | namibe
# Processing Record 37 of Set 10 | iralaya
# Processing Record 38 of Set 10 | upernavik
# Processing Record 39 of Set 10 | fort nelson
# Processing Record 40 of Set 10 | sucua
# Processing Record 41 of Set 10 | ust-kamchatsk
# Error for while looking for information on ust-kamchatsk at entry 491
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 10 | mogadishu
# Processing Record 43 of Set 10 | kathu
# Processing Record 44 of Set 10 | ignatovka
# Processing Record 45 of Set 10 | moose factory
# Processing Record 46 of Set 10 | kirakira
# Processing Record 47 of Set 10 | cherdyn
# Processing Record 48 of Set 10 | egvekinot
# Processing Record 49 of Set 10 | ronne
# Processing Record 50 of Set 10 | wembley
# Processing Record 1 of Set 11 | ambunti
# Processing Record 2 of Set 11 | wewak
# Processing Record 3 of Set 11 | qui nhon
# Processing Record 4 of Set 11 | hastings
# Processing Record 5 of Set 11 | kargasok
# Processing Record 6 of Set 11 | otukpo
# Processing Record 7 of Set 11 | salamanca
# Processing Record 8 of Set 11 | cah ab
# Error for while looking for information on cah ab at entry 508
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 11 | ulaangom
# Processing Record 10 of Set 11 | ossora
# Processing Record 11 of Set 11 | rochegda
# Processing Record 12 of Set 11 | varkkallai
# Processing Record 13 of Set 11 | gazli
# Processing Record 14 of Set 11 | trairi
# Processing Record 15 of Set 11 | zabid
# Processing Record 16 of Set 11 | te anau
# Processing Record 17 of Set 11 | turbat
# Processing Record 18 of Set 11 | okha
# Processing Record 19 of Set 11 | vostok
# Processing Record 20 of Set 11 | chumikan
# Processing Record 21 of Set 11 | ponnani
# Processing Record 22 of Set 11 | bathsheba
# Processing Record 23 of Set 11 | dayong
# Processing Record 24 of Set 11 | binga
# Processing Record 25 of Set 11 | arbuzynka
# Processing Record 26 of Set 11 | quatre cocos
# Processing Record 27 of Set 11 | sungaipenuh
# Processing Record 28 of Set 11 | college
# Processing Record 29 of Set 11 | ust-kut
# Processing Record 30 of Set 11 | kanigoro
# Processing Record 31 of Set 11 | taburao
# Error for while looking for information on taburao at entry 531
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 11 | vallenar
# Processing Record 33 of Set 11 | raigarh
# Processing Record 34 of Set 11 | port-gentil
# Processing Record 35 of Set 11 | laurel
# Processing Record 36 of Set 11 | burgeo
# Processing Record 37 of Set 11 | svetlogorsk
# Processing Record 38 of Set 11 | nanning
# Processing Record 39 of Set 11 | tamandare
# Processing Record 40 of Set 11 | vung tau
# Processing Record 41 of Set 11 | beidao
# Processing Record 42 of Set 11 | seminole
# Processing Record 43 of Set 11 | sorvag
# Error for while looking for information on sorvag at entry 543
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 11 | verkhnyaya maksakovka
# Processing Record 45 of Set 11 | lazaro cardenas
# Processing Record 46 of Set 11 | lebowakgomo
# Processing Record 47 of Set 11 | macaboboni
# Error for while looking for information on macaboboni at entry 547
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 11 | knysna
# Processing Record 49 of Set 11 | fairview
# Processing Record 50 of Set 11 | wad madani
# Processing Record 1 of Set 12 | oktyabrskoye
# Processing Record 2 of Set 12 | paka
# Processing Record 3 of Set 12 | tateyama
# Processing Record 4 of Set 12 | dubbo
# Processing Record 5 of Set 12 | encruzilhada
# Processing Record 6 of Set 12 | pacific grove
# Processing Record 7 of Set 12 | rio grande
# Processing Record 8 of Set 12 | waterville
# Processing Record 9 of Set 12 | lolua
# Error for while looking for information on lolua at entry 559
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 12 | zemio
# Processing Record 11 of Set 12 | buala
# Processing Record 12 of Set 12 | kudahuvadhoo
# Processing Record 13 of Set 12 | spassk-dalniy
# Processing Record 14 of Set 12 | alyangula
# Processing Record 15 of Set 12 | inhambane
# Processing Record 16 of Set 12 | along
# Processing Record 17 of Set 12 | sibolga
# Processing Record 18 of Set 12 | fairbanks
# Processing Record 19 of Set 12 | vanimo
# Processing Record 20 of Set 12 | iquique
# Processing Record 21 of Set 12 | maumere
# Processing Record 22 of Set 12 | impfondo
# Processing Record 23 of Set 12 | changping
# Processing Record 24 of Set 12 | muskegon
# Processing Record 25 of Set 12 | mandalgovi
# Processing Record 26 of Set 12 | kastamonu
# Processing Record 27 of Set 12 | bilibino
# Processing Record 28 of Set 12 | aborlan
# Processing Record 29 of Set 12 | puerto escondido
# Processing Record 30 of Set 12 | makakilo city
# Processing Record 31 of Set 12 | talara
# Processing Record 32 of Set 12 | chakrata
# Processing Record 33 of Set 12 | verkh-chebula
# Processing Record 34 of Set 12 | selishche
# Processing Record 35 of Set 12 | seydi
# Processing Record 36 of Set 12 | kavaratti
# Processing Record 37 of Set 12 | borovichi
# Processing Record 38 of Set 12 | tabou
# Processing Record 39 of Set 12 | hanna
# Processing Record 40 of Set 12 | batesville
# Processing Record 41 of Set 12 | nijar
# Processing Record 42 of Set 12 | brodick
# Processing Record 43 of Set 12 | bambanglipuro
# Processing Record 44 of Set 12 | etampes
# Processing Record 45 of Set 12 | sangar
# Processing Record 46 of Set 12 | aksu
# Processing Record 47 of Set 12 | ca mau
# Processing Record 48 of Set 12 | risor
# Processing Record 49 of Set 12 | la cruz
# Processing Record 50 of Set 12 | gao
# Processing Record 1 of Set 13 | tucuma
# Processing Record 2 of Set 13 | skjaerhollen
# Error for while looking for information on skjaerhollen at entry 602
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 13 | barabai
# Processing Record 4 of Set 13 | el balyana
# Error for while looking for information on el balyana at entry 604
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 13 | soma
# Processing Record 6 of Set 13 | zolotukhino
# Processing Record 7 of Set 13 | noumea
# Processing Record 8 of Set 13 | richards bay
# Processing Record 9 of Set 13 | ahtopol
# Processing Record 10 of Set 13 | hami
# Processing Record 11 of Set 13 | rawson
# Processing Record 12 of Set 13 | livingston
# Processing Record 13 of Set 13 | nuevitas
# Processing Record 14 of Set 13 | abu zabad
# Processing Record 15 of Set 13 | malakisi
# Error for while looking for information on malakisi at entry 615
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 13 | chavantes
# Processing Record 17 of Set 13 | hihifo
# Error for while looking for information on hihifo at entry 617
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 13 | nienburg
# Processing Record 19 of Set 13 | sioux lookout
# Processing Record 20 of Set 13 | bereda
# Processing Record 21 of Set 13 | tiksi
# Processing Record 22 of Set 13 | itaituba
# Processing Record 23 of Set 13 | marcona
# Error for while looking for information on marcona at entry 623
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 13 | nikolayevsk-na-amure
# Processing Record 25 of Set 13 | saint-louis
# Processing Record 26 of Set 13 | castro-urdiales
# Processing Record 27 of Set 13 | lorengau
# Processing Record 28 of Set 13 | lima
# Processing Record 29 of Set 13 | asmara
# Processing Record 30 of Set 13 | abu dhabi
# Processing Record 31 of Set 13 | jurm
# Processing Record 32 of Set 13 | virginia beach
# Processing Record 33 of Set 13 | kiama
# Processing Record 34 of Set 13 | artyk
# Error for while looking for information on artyk at entry 634
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 13 | adrar
# Processing Record 36 of Set 13 | verkhnevilyuysk
# Processing Record 37 of Set 13 | teya
# Processing Record 38 of Set 13 | szany
# Processing Record 39 of Set 13 | dunkirk
# Processing Record 40 of Set 13 | calatayud
# Processing Record 41 of Set 13 | atkinson
# Processing Record 42 of Set 13 | port blair
# Processing Record 43 of Set 13 | palmer
# Processing Record 44 of Set 13 | umzimvubu
# Error for while looking for information on umzimvubu at entry 644
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 13 | chifeng
# Processing Record 46 of Set 13 | moree
# Processing Record 47 of Set 13 | santa eulalia del rio
# Error for while looking for information on santa eulalia del rio at entry 647
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 13 | wencheng
# Processing Record 49 of Set 13 | leh
# Processing Record 50 of Set 13 | kingaroy
# Processing Record 1 of Set 14 | manta
# Processing Record 2 of Set 14 | sao miguel do araguaia
# Processing Record 3 of Set 14 | muli
# Processing Record 4 of Set 14 | litovko
# Processing Record 5 of Set 14 | tecoanapa
# Processing Record 6 of Set 14 | seoul
# Processing Record 7 of Set 14 | meulaboh
# Processing Record 8 of Set 14 | praia da vitoria
# Processing Record 9 of Set 14 | tomatlan
# Processing Record 10 of Set 14 | mariental
# Processing Record 11 of Set 14 | todos santos
# Processing Record 12 of Set 14 | bayonet point
# Processing Record 13 of Set 14 | bull savanna
# Processing Record 14 of Set 14 | luau
# Processing Record 15 of Set 14 | hella
# Processing Record 16 of Set 14 | plaeng yao
# Processing Record 17 of Set 14 | conakry
# Processing Record 18 of Set 14 | sosua
# Processing Record 19 of Set 14 | indianola
# Processing Record 20 of Set 14 | pasinler
# Processing Record 21 of Set 14 | chapais
# Processing Record 22 of Set 14 | novo aripuana
# Processing Record 23 of Set 14 | saiha
# Processing Record 24 of Set 14 | tabuk
# Processing Record 25 of Set 14 | bucerias
# Processing Record 26 of Set 14 | srandakan
# Processing Record 27 of Set 14 | tukrah
# Processing Record 28 of Set 14 | tiznit
# Processing Record 29 of Set 14 | fukuma
# Processing Record 30 of Set 14 | yarada
# Processing Record 31 of Set 14 | talawdi
# Error for while looking for information on talawdi at entry 681
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 14 | port moresby
# Processing Record 33 of Set 14 | tasbuget
# Error for while looking for information on tasbuget at entry 683
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 14 | winneba
# Processing Record 35 of Set 14 | vigrestad
# Processing Record 36 of Set 14 | tianpeng
# Processing Record 37 of Set 14 | kattivakkam
# Processing Record 38 of Set 14 | koshki
# Processing Record 39 of Set 14 | maceio
# Processing Record 40 of Set 14 | shieli
# Processing Record 41 of Set 14 | virtsu
# Processing Record 42 of Set 14 | havre-saint-pierre
# Processing Record 43 of Set 14 | westport
# Processing Record 44 of Set 14 | turukhansk
# Processing Record 45 of Set 14 | dukat
# Processing Record 46 of Set 14 | waingapu
# Processing Record 47 of Set 14 | liwale
# Processing Record 48 of Set 14 | prado
# Processing Record 49 of Set 14 | coihueco
# Processing Record 50 of Set 14 | narasannapeta
# Processing Record 1 of Set 15 | raga
# Processing Record 2 of Set 15 | sabzevar
# Processing Record 3 of Set 15 | novyy yegorlyk
# Processing Record 4 of Set 15 | severnyy
# Processing Record 5 of Set 15 | otjiwarongo
# Processing Record 6 of Set 15 | nanzhang
# Processing Record 7 of Set 15 | peace river
# Processing Record 8 of Set 15 | zyryanka
# Processing Record 9 of Set 15 | tarakan
# Processing Record 10 of Set 15 | prescott
# Processing Record 11 of Set 15 | carson city
# Processing Record 12 of Set 15 | fremont
# Processing Record 13 of Set 15 | tapes
# Processing Record 14 of Set 15 | copiapo
# Processing Record 15 of Set 15 | shulan
# Processing Record 16 of Set 15 | nantucket
# Processing Record 17 of Set 15 | san jeronimo
# Processing Record 18 of Set 15 | hualmay
# Processing Record 19 of Set 15 | alice springs
# Processing Record 20 of Set 15 | high rock
# Processing Record 21 of Set 15 | moa
# Processing Record 22 of Set 15 | derzhavinsk
# Processing Record 23 of Set 15 | saint anthony
# Processing Record 24 of Set 15 | nehe
# Processing Record 25 of Set 15 | bud
# Processing Record 26 of Set 15 | valdivia
# Processing Record 27 of Set 15 | les cayes
# Processing Record 28 of Set 15 | semenivka
# Processing Record 29 of Set 15 | korla
# Processing Record 30 of Set 15 | grand centre
# Error for while looking for information on grand centre at entry 730
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 15 | lemoore
# Processing Record 32 of Set 15 | douentza
# Processing Record 33 of Set 15 | cheremkhovo
# Processing Record 34 of Set 15 | samana
# Processing Record 35 of Set 15 | kofele
# Processing Record 36 of Set 15 | deh rawud
# Error for while looking for information on deh rawud at entry 736
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 15 | montepuez
# Processing Record 38 of Set 15 | yirol
# Error for while looking for information on yirol at entry 738
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 15 | dzhusaly
# Error for while looking for information on dzhusaly at entry 739
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 15 | roma
# Processing Record 41 of Set 15 | kedrovyy
# Processing Record 42 of Set 15 | eidfjord
# Processing Record 43 of Set 15 | isiro
# Processing Record 44 of Set 15 | praia
# Processing Record 45 of Set 15 | lages
# Processing Record 46 of Set 15 | ecoporanga
# Processing Record 47 of Set 15 | manoel urbano
# Processing Record 48 of Set 15 | cibitoke
# Processing Record 49 of Set 15 | sept-iles
# Processing Record 50 of Set 15 | hun
# Processing Record 1 of Set 16 | oskemen
# Processing Record 2 of Set 16 | darnah
# Processing Record 3 of Set 16 | diamantino
# Processing Record 4 of Set 16 | opuwo
# Processing Record 5 of Set 16 | neuquen
# Processing Record 6 of Set 16 | pasighat
# Processing Record 7 of Set 16 | viligili
# Error for while looking for information on viligili at entry 757
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 16 | teknaf
# Processing Record 9 of Set 16 | karamea
# Error for while looking for information on karamea at entry 759
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 16 | jiancheng
# Processing Record 11 of Set 16 | iranshahr
# Processing Record 12 of Set 16 | wanaka
# Processing Record 13 of Set 16 | aljezur
# Processing Record 14 of Set 16 | gallipoli
# Processing Record 15 of Set 16 | talavera
# Processing Record 16 of Set 16 | buariki
# Error for while looking for information on buariki at entry 766
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 16 | matagami
# Processing Record 18 of Set 16 | santo tomas
# Processing Record 19 of Set 16 | comodoro rivadavia
# Processing Record 20 of Set 16 | gimli
# Processing Record 21 of Set 16 | vyartsilya
# Processing Record 22 of Set 16 | christchurch
# ---------------------------------
#     Data Retrieval Complete
# ---------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       ushuaia      AR -54.8000  -68.3000     37.06        81           0
# 1        castro      BR -24.7911  -50.0119     63.07        73          99
# 2     barbacoas      CO   1.6715  -78.1398     85.24        67          86
# 3         vaini      TO -21.2000 -175.2000     69.96       100          20
# 4  barra patuca      HN  15.8000  -84.2833     81.91        83          97
# 5    georgetown      MY   5.4112  100.3354     80.89        82          20
# 6     cape town      ZA -33.9258   18.4232     58.91        74           0
# 7   tuktoyaktuk      CA  69.4541 -133.0374     55.40        94         100
# 8     caravelas      BR -17.7125  -39.2481     78.19        65          66
# 9   clyde river      CA  70.4692  -68.5914     43.03        81         100
#
#    Wind Speed Current Description
# 0        2.30           clear sky
# 1        5.59          light rain
# 2        4.65          light rain
# 3        2.30          few clouds
# 4       11.99     overcast clouds
# 5        2.30          few clouds
# 6       15.01           clear sky
# 7       17.27          light rain
# 8        6.91       broken clouds
# 9       19.57     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
