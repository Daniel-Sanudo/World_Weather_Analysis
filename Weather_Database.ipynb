# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from citipy import citipy

#Import the OpenWeather key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats, lngs)
coordinates

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Define the static parameters for the request
OW_key = weather_api_key
OW_units = "imperial"

# Define the base url
OW_url = "https://api.openweathermap.org/data/2.5/weather?q="

# The url should look like this:
# https://api.openweathermap.org/data/2.5/weather?q={city name}&units={Units}&appid={API key}

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("--------------------------------")
print("    Beginning Data Retrieval    ")
print("--------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Change spaces for plus signs to avoid url errors
    OW_city = city.replace(" ","+")
    
    # Create endpoint URL with each city.
    city_url = f"{OW_url}{OW_city}&units={OW_units}&appid={OW_key}"
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except Exception as e:
        
        print(f"Error for while looking for information on {city} at entry {50 * (set_count - 1 ) + record_count - 1}")
        print(f"Received the following error: {e}")
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("---------------------------------")
print("    Data Retrieval Complete      ")
print("---------------------------------")
# Out:
# --------------------------------
#     Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | taolanaro
# Error for while looking for information on taolanaro at entry 3
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | manokwari
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | amderma
# Error for while looking for information on amderma at entry 7
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 1 | wewak
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | lompoc
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | torbay
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | goryachegorsk
# Processing Record 17 of Set 1 | marawi
# Processing Record 18 of Set 1 | bac lieu
# Processing Record 19 of Set 1 | sidhi
# Processing Record 20 of Set 1 | bajo baudo
# Error for while looking for information on bajo baudo at entry 20
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 1 | tautira
# Processing Record 22 of Set 1 | lufilufi
# Processing Record 23 of Set 1 | esperance
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | samalaeulu
# Error for while looking for information on samalaeulu at entry 26
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | thompson
# Processing Record 30 of Set 1 | nizhneyansk
# Error for while looking for information on nizhneyansk at entry 30
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | alto araguaia
# Processing Record 34 of Set 1 | pangnirtung
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | komsomolskiy
# Processing Record 38 of Set 1 | rabo de peixe
# Processing Record 39 of Set 1 | hayvoron
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | kemalpasa
# Processing Record 44 of Set 1 | domoni
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | avera
# Processing Record 47 of Set 1 | jalu
# Processing Record 48 of Set 1 | marsh harbour
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | cam ranh
# Processing Record 1 of Set 2 | narsaq
# Processing Record 2 of Set 2 | port lincoln
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | vanavara
# Processing Record 5 of Set 2 | olafsvik
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | vila velha
# Processing Record 9 of Set 2 | bodden town
# Processing Record 10 of Set 2 | shadegan
# Processing Record 11 of Set 2 | gander
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | faanui
# Processing Record 15 of Set 2 | scottsburgh
# Error for while looking for information on scottsburgh at entry 65
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | lexington
# Processing Record 19 of Set 2 | cidreira
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | dianopolis
# Error for while looking for information on dianopolis at entry 71
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 2 | tsihombe
# Error for while looking for information on tsihombe at entry 72
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 2 | nueva guinea
# Processing Record 24 of Set 2 | la ronge
# Processing Record 25 of Set 2 | saint george
# Processing Record 26 of Set 2 | nome
# Processing Record 27 of Set 2 | arraias
# Processing Record 28 of Set 2 | grand river south east
# Error for while looking for information on grand river south east at entry 78
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 2 | fortuna
# Processing Record 30 of Set 2 | mackay
# Processing Record 31 of Set 2 | akdepe
# Processing Record 32 of Set 2 | bayeux
# Processing Record 33 of Set 2 | baraut
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | shimoda
# Processing Record 37 of Set 2 | dali
# Processing Record 38 of Set 2 | coihaique
# Processing Record 39 of Set 2 | barentsburg
# Error for while looking for information on barentsburg at entry 89
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 2 | springfield
# Processing Record 41 of Set 2 | papara
# Processing Record 42 of Set 2 | aklavik
# Processing Record 43 of Set 2 | lorengau
# Processing Record 44 of Set 2 | ginir
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | guerrero negro
# Processing Record 47 of Set 2 | pisco
# Processing Record 48 of Set 2 | te anau
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | vao
# Processing Record 1 of Set 3 | kamenka
# Processing Record 2 of Set 3 | borovoy
# Processing Record 3 of Set 3 | necochea
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | saint-joseph
# Processing Record 7 of Set 3 | abu samrah
# Processing Record 8 of Set 3 | port blair
# Processing Record 9 of Set 3 | hovd
# Processing Record 10 of Set 3 | barcelos
# Processing Record 11 of Set 3 | jaciara
# Processing Record 12 of Set 3 | muscat
# Processing Record 13 of Set 3 | port hardy
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | castro
# Processing Record 16 of Set 3 | belushya guba
# Error for while looking for information on belushya guba at entry 116
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | avarua
# Processing Record 20 of Set 3 | artyk
# Error for while looking for information on artyk at entry 120
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | kumba
# Processing Record 23 of Set 3 | victoria
# Processing Record 24 of Set 3 | katherine
# Processing Record 25 of Set 3 | puerto lopez
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | impfondo
# Processing Record 28 of Set 3 | jumla
# Processing Record 29 of Set 3 | ovruch
# Processing Record 30 of Set 3 | peniche
# Processing Record 31 of Set 3 | marquette
# Processing Record 32 of Set 3 | cascais
# Processing Record 33 of Set 3 | hervey bay
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | pangkalanbuun
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | iwanai
# Processing Record 38 of Set 3 | mastung
# Processing Record 39 of Set 3 | touros
# Processing Record 40 of Set 3 | ahuimanu
# Processing Record 41 of Set 3 | nadym
# Processing Record 42 of Set 3 | gibsons
# Processing Record 43 of Set 3 | cherskiy
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | asau
# Processing Record 46 of Set 3 | aksu
# Processing Record 47 of Set 3 | karonga
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | saint-philippe
# Processing Record 1 of Set 4 | nanortalik
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | gerede
# Processing Record 4 of Set 4 | whitianga
# Processing Record 5 of Set 4 | evensk
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | ambilobe
# Processing Record 8 of Set 4 | tilichiki
# Processing Record 9 of Set 4 | alexandria
# Processing Record 10 of Set 4 | media luna
# Processing Record 11 of Set 4 | nishiwaki
# Processing Record 12 of Set 4 | sobolevo
# Processing Record 13 of Set 4 | lalmohan
# Processing Record 14 of Set 4 | jamestown
# Processing Record 15 of Set 4 | cayenne
# Processing Record 16 of Set 4 | yar-sale
# Processing Record 17 of Set 4 | tiarei
# Processing Record 18 of Set 4 | uwayl
# Error for while looking for information on uwayl at entry 168
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 4 | bilma
# Processing Record 20 of Set 4 | maceio
# Processing Record 21 of Set 4 | kununurra
# Processing Record 22 of Set 4 | hofn
# Processing Record 23 of Set 4 | salalah
# Processing Record 24 of Set 4 | gashua
# Processing Record 25 of Set 4 | geraldton
# Processing Record 26 of Set 4 | berlevag
# Processing Record 27 of Set 4 | shenjiamen
# Processing Record 28 of Set 4 | satitoa
# Error for while looking for information on satitoa at entry 178
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 4 | chupa
# Processing Record 30 of Set 4 | prachuap khiri khan
# Processing Record 31 of Set 4 | norman wells
# Processing Record 32 of Set 4 | padang
# Processing Record 33 of Set 4 | barawe
# Error for while looking for information on barawe at entry 183
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 4 | sentyabrskiy
# Error for while looking for information on sentyabrskiy at entry 184
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 4 | ancud
# Processing Record 36 of Set 4 | puerto ayora
# Processing Record 37 of Set 4 | grindavik
# Processing Record 38 of Set 4 | fort nelson
# Processing Record 39 of Set 4 | kuche
# Error for while looking for information on kuche at entry 189
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 4 | pitimbu
# Processing Record 41 of Set 4 | airai
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | boyolangu
# Processing Record 44 of Set 4 | paamiut
# Processing Record 45 of Set 4 | kawalu
# Processing Record 46 of Set 4 | lagoa
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | yakeshi
# Processing Record 49 of Set 4 | portland
# Processing Record 50 of Set 4 | port pirie
# Processing Record 1 of Set 5 | farsund
# Processing Record 2 of Set 5 | tual
# Processing Record 3 of Set 5 | ostrovnoy
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | palana
# Processing Record 6 of Set 5 | khovu-aksy
# Processing Record 7 of Set 5 | buala
# Processing Record 8 of Set 5 | illoqqortoormiut
# Error for while looking for information on illoqqortoormiut at entry 208
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 5 | lakota
# Processing Record 10 of Set 5 | alotau
# Error for while looking for information on alotau at entry 210
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 5 | tandil
# Processing Record 12 of Set 5 | demmin
# Processing Record 13 of Set 5 | kerteh
# Error for while looking for information on kerteh at entry 213
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 5 | manuk mangkaw
# Processing Record 15 of Set 5 | san patricio
# Processing Record 16 of Set 5 | high level
# Processing Record 17 of Set 5 | tekeli
# Processing Record 18 of Set 5 | yian
# Error for while looking for information on yian at entry 218
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 5 | urengoy
# Processing Record 20 of Set 5 | balvi
# Processing Record 21 of Set 5 | vyartsilya
# Processing Record 22 of Set 5 | caluquembe
# Processing Record 23 of Set 5 | mys shmidta
# Error for while looking for information on mys shmidta at entry 223
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 5 | atherton
# Processing Record 25 of Set 5 | camopi
# Processing Record 26 of Set 5 | auki
# Processing Record 27 of Set 5 | lavrentiya
# Processing Record 28 of Set 5 | warqla
# Error for while looking for information on warqla at entry 228
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 5 | poya
# Processing Record 30 of Set 5 | santa isabel
# Processing Record 31 of Set 5 | nishihara
# Processing Record 32 of Set 5 | lebu
# Processing Record 33 of Set 5 | havoysund
# Processing Record 34 of Set 5 | tambura
# Processing Record 35 of Set 5 | attawapiskat
# Error for while looking for information on attawapiskat at entry 235
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 5 | nemuro
# Processing Record 37 of Set 5 | lipari
# Processing Record 38 of Set 5 | almaznyy
# Processing Record 39 of Set 5 | badarwas
# Processing Record 40 of Set 5 | narragansett
# Processing Record 41 of Set 5 | maarianhamina
# Processing Record 42 of Set 5 | sativasur
# Processing Record 43 of Set 5 | qaanaaq
# Processing Record 44 of Set 5 | kushima
# Processing Record 45 of Set 5 | omboue
# Processing Record 46 of Set 5 | kaitangata
# Processing Record 47 of Set 5 | saryshagan
# Error for while looking for information on saryshagan at entry 247
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 5 | broome
# Processing Record 49 of Set 5 | grand centre
# Error for while looking for information on grand centre at entry 249
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 5 | pokhara
# Processing Record 1 of Set 6 | bulembu
# Processing Record 2 of Set 6 | port macquarie
# Processing Record 3 of Set 6 | muisne
# Processing Record 4 of Set 6 | ozgon
# Error for while looking for information on ozgon at entry 254
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 6 | flin flon
# Processing Record 6 of Set 6 | sault sainte marie
# Processing Record 7 of Set 6 | ambon
# Processing Record 8 of Set 6 | ulaangom
# Processing Record 9 of Set 6 | lodja
# Processing Record 10 of Set 6 | moratuwa
# Processing Record 11 of Set 6 | faya
# Processing Record 12 of Set 6 | sur
# Processing Record 13 of Set 6 | tanete
# Processing Record 14 of Set 6 | goderich
# Processing Record 15 of Set 6 | tambul
# Error for while looking for information on tambul at entry 265
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 6 | tuzha
# Processing Record 17 of Set 6 | isangel
# Processing Record 18 of Set 6 | buchanan
# Processing Record 19 of Set 6 | haicheng
# Processing Record 20 of Set 6 | manicore
# Processing Record 21 of Set 6 | vung tau
# Processing Record 22 of Set 6 | walvis bay
# Processing Record 23 of Set 6 | george
# Processing Record 24 of Set 6 | san andres
# Processing Record 25 of Set 6 | scottsbluff
# Processing Record 26 of Set 6 | mehamn
# Processing Record 27 of Set 6 | luderitz
# Processing Record 28 of Set 6 | vardo
# Processing Record 29 of Set 6 | manakara
# Processing Record 30 of Set 6 | benalla
# Processing Record 31 of Set 6 | ahipara
# Processing Record 32 of Set 6 | meyungs
# Error for while looking for information on meyungs at entry 282
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 6 | algiers
# Processing Record 34 of Set 6 | constitucion
# Processing Record 35 of Set 6 | mastic beach
# Processing Record 36 of Set 6 | ternate
# Processing Record 37 of Set 6 | lukovetskiy
# Processing Record 38 of Set 6 | tumannyy
# Error for while looking for information on tumannyy at entry 288
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | pongpong
# Error for while looking for information on pongpong at entry 290
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 6 | vestmannaeyjar
# Processing Record 42 of Set 6 | payson
# Processing Record 43 of Set 6 | new norfolk
# Processing Record 44 of Set 6 | san joaquin
# Processing Record 45 of Set 6 | griffith
# Processing Record 46 of Set 6 | kahului
# Processing Record 47 of Set 6 | gravelbourg
# Processing Record 48 of Set 6 | sao sebastiao do cai
# Processing Record 49 of Set 6 | axim
# Processing Record 50 of Set 6 | bathsheba
# Processing Record 1 of Set 7 | along
# Processing Record 2 of Set 7 | oussouye
# Processing Record 3 of Set 7 | mahon
# Processing Record 4 of Set 7 | dingle
# Processing Record 5 of Set 7 | zapolyarnyy
# Processing Record 6 of Set 7 | surt
# Processing Record 7 of Set 7 | show low
# Processing Record 8 of Set 7 | kudahuvadhoo
# Processing Record 9 of Set 7 | lusaka
# Processing Record 10 of Set 7 | gat
# Processing Record 11 of Set 7 | ugoofaaru
# Processing Record 12 of Set 7 | pevek
# Processing Record 13 of Set 7 | isetskoye
# Processing Record 14 of Set 7 | woodward
# Processing Record 15 of Set 7 | barra
# Processing Record 16 of Set 7 | westport
# Processing Record 17 of Set 7 | saint-andre-avellin
# Processing Record 18 of Set 7 | northam
# Processing Record 19 of Set 7 | saldanha
# Processing Record 20 of Set 7 | shaartuz
# Error for while looking for information on shaartuz at entry 320
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 7 | yining
# Processing Record 22 of Set 7 | trairi
# Processing Record 23 of Set 7 | marystown
# Processing Record 24 of Set 7 | tuy hoa
# Processing Record 25 of Set 7 | key largo
# Processing Record 26 of Set 7 | solwezi
# Processing Record 27 of Set 7 | teknaf
# Processing Record 28 of Set 7 | hohhot
# Processing Record 29 of Set 7 | gejiu
# Processing Record 30 of Set 7 | sable-sur-sarthe
# Processing Record 31 of Set 7 | klaksvik
# Processing Record 32 of Set 7 | snezhnogorsk
# Processing Record 33 of Set 7 | mount gambier
# Processing Record 34 of Set 7 | pozo colorado
# Processing Record 35 of Set 7 | ijaki
# Error for while looking for information on ijaki at entry 335
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 7 | san jose
# Processing Record 37 of Set 7 | tiznit
# Processing Record 38 of Set 7 | somerset east
# Processing Record 39 of Set 7 | saint-georges
# Processing Record 40 of Set 7 | wulanhaote
# Error for while looking for information on wulanhaote at entry 340
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 7 | vostok
# Processing Record 42 of Set 7 | khartoum
# Processing Record 43 of Set 7 | hay river
# Processing Record 44 of Set 7 | zhigansk
# Processing Record 45 of Set 7 | ust-koksa
# Processing Record 46 of Set 7 | nikolskoye
# Processing Record 47 of Set 7 | puerto del rosario
# Processing Record 48 of Set 7 | alofi
# Processing Record 49 of Set 7 | ondangwa
# Processing Record 50 of Set 7 | danilovka
# Processing Record 1 of Set 8 | biak
# Processing Record 2 of Set 8 | bolungarvik
# Error for while looking for information on bolungarvik at entry 352
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 8 | pindiga
# Processing Record 4 of Set 8 | camacha
# Processing Record 5 of Set 8 | rawson
# Processing Record 6 of Set 8 | ballyshannon
# Processing Record 7 of Set 8 | liaoyang
# Processing Record 8 of Set 8 | veselynove
# Processing Record 9 of Set 8 | chauk
# Processing Record 10 of Set 8 | longyearbyen
# Processing Record 11 of Set 8 | aligudarz
# Processing Record 12 of Set 8 | lolua
# Error for while looking for information on lolua at entry 362
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 8 | leningradskiy
# Processing Record 14 of Set 8 | umm durman
# Error for while looking for information on umm durman at entry 364
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 8 | port-gentil
# Processing Record 16 of Set 8 | phan thiet
# Processing Record 17 of Set 8 | san lazaro
# Processing Record 18 of Set 8 | exeter
# Processing Record 19 of Set 8 | pouembout
# Processing Record 20 of Set 8 | kunming
# Processing Record 21 of Set 8 | labuhan
# Processing Record 22 of Set 8 | soreang
# Processing Record 23 of Set 8 | nouadhibou
# Processing Record 24 of Set 8 | luganville
# Processing Record 25 of Set 8 | voi
# Processing Record 26 of Set 8 | gurgan
# Error for while looking for information on gurgan at entry 376
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 8 | mogadishu
# Processing Record 28 of Set 8 | havre-saint-pierre
# Processing Record 29 of Set 8 | kisangani
# Processing Record 30 of Set 8 | fuzhou
# Processing Record 31 of Set 8 | gladstone
# Processing Record 32 of Set 8 | wolsztyn
# Processing Record 33 of Set 8 | kamina
# Processing Record 34 of Set 8 | cockburn town
# Processing Record 35 of Set 8 | hambantota
# Processing Record 36 of Set 8 | pijijiapan
# Processing Record 37 of Set 8 | dubbo
# Processing Record 38 of Set 8 | ballina
# Processing Record 39 of Set 8 | partizanskoye
# Processing Record 40 of Set 8 | shaowu
# Processing Record 41 of Set 8 | maunabo
# Processing Record 42 of Set 8 | ambovombe
# Processing Record 43 of Set 8 | harper
# Processing Record 44 of Set 8 | merauke
# Processing Record 45 of Set 8 | tura
# Processing Record 46 of Set 8 | vanimo
# Processing Record 47 of Set 8 | tuatapere
# Processing Record 48 of Set 8 | half moon bay
# Processing Record 49 of Set 8 | gazli
# Processing Record 50 of Set 8 | saint-francois
# Processing Record 1 of Set 9 | bud
# Processing Record 2 of Set 9 | chagda
# Error for while looking for information on chagda at entry 402
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 9 | palabuhanratu
# Error for while looking for information on palabuhanratu at entry 403
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 9 | hobyo
# Processing Record 5 of Set 9 | halalo
# Error for while looking for information on halalo at entry 405
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 9 | bakani
# Processing Record 7 of Set 9 | kawana waters
# Error for while looking for information on kawana waters at entry 407
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 9 | manggar
# Processing Record 9 of Set 9 | olenino
# Processing Record 10 of Set 9 | neuquen
# Processing Record 11 of Set 9 | evansville
# Processing Record 12 of Set 9 | kusk
# Error for while looking for information on kusk at entry 412
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 9 | marsa matruh
# Processing Record 14 of Set 9 | havelock
# Processing Record 15 of Set 9 | galesong
# Processing Record 16 of Set 9 | babushkin
# Processing Record 17 of Set 9 | fukue
# Processing Record 18 of Set 9 | turochak
# Processing Record 19 of Set 9 | kutum
# Processing Record 20 of Set 9 | athenry
# Processing Record 21 of Set 9 | maralal
# Processing Record 22 of Set 9 | tahta
# Processing Record 23 of Set 9 | kharp
# Processing Record 24 of Set 9 | mrirt
# Error for while looking for information on mrirt at entry 424
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 9 | pacific grove
# Processing Record 26 of Set 9 | iqaluit
# Processing Record 27 of Set 9 | azle
# Processing Record 28 of Set 9 | clyde river
# Processing Record 29 of Set 9 | kathu
# Processing Record 30 of Set 9 | eastlake
# Processing Record 31 of Set 9 | dicabisagan
# Processing Record 32 of Set 9 | samusu
# Error for while looking for information on samusu at entry 432
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 9 | sinnamary
# Processing Record 34 of Set 9 | bengkulu
# Processing Record 35 of Set 9 | le moule
# Processing Record 36 of Set 9 | melo
# Processing Record 37 of Set 9 | wasilla
# Processing Record 38 of Set 9 | kostalexis
# Processing Record 39 of Set 9 | delaware
# Processing Record 40 of Set 9 | sabang
# Processing Record 41 of Set 9 | mpika
# Processing Record 42 of Set 9 | knysna
# Processing Record 43 of Set 9 | estelle
# Processing Record 44 of Set 9 | tarakan
# Processing Record 45 of Set 9 | anadyr
# Processing Record 46 of Set 9 | bubaque
# Processing Record 47 of Set 9 | viligili
# Error for while looking for information on viligili at entry 447
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 9 | sao paulo de olivenca
# Processing Record 49 of Set 9 | coari
# Processing Record 50 of Set 9 | lata
# Processing Record 1 of Set 10 | hearst
# Processing Record 2 of Set 10 | tasgaon
# Processing Record 3 of Set 10 | doha
# Processing Record 4 of Set 10 | maloshuyka
# Error for while looking for information on maloshuyka at entry 454
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 10 | fairbanks
# Processing Record 6 of Set 10 | meadow lake
# Processing Record 7 of Set 10 | tessalit
# Processing Record 8 of Set 10 | alice springs
# Processing Record 9 of Set 10 | umzimvubu
# Error for while looking for information on umzimvubu at entry 459
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 10 | dunedin
# Processing Record 11 of Set 10 | khani
# Processing Record 12 of Set 10 | saransk
# Processing Record 13 of Set 10 | plettenberg bay
# Processing Record 14 of Set 10 | port moresby
# Processing Record 15 of Set 10 | alyangula
# Processing Record 16 of Set 10 | formosa
# Processing Record 17 of Set 10 | bandar-e lengeh
# Processing Record 18 of Set 10 | nelson bay
# Processing Record 19 of Set 10 | vaitupu
# Error for while looking for information on vaitupu at entry 469
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 10 | visby
# Processing Record 21 of Set 10 | juifang
# Error for while looking for information on juifang at entry 471
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 10 | aquiraz
# Processing Record 23 of Set 10 | west bay
# Processing Record 24 of Set 10 | fez
# Processing Record 25 of Set 10 | tuggurt
# Error for while looking for information on tuggurt at entry 475
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 10 | port hueneme
# Processing Record 27 of Set 10 | vega de alatorre
# Processing Record 28 of Set 10 | umm kaddadah
# Processing Record 29 of Set 10 | mlonggo
# Processing Record 30 of Set 10 | rio branco
# Processing Record 31 of Set 10 | volokonovka
# Processing Record 32 of Set 10 | mana
# Processing Record 33 of Set 10 | erenhot
# Processing Record 34 of Set 10 | naberera
# Processing Record 35 of Set 10 | sibolga
# Processing Record 36 of Set 10 | saleaula
# Error for while looking for information on saleaula at entry 486
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 10 | dibaya
# Error for while looking for information on dibaya at entry 487
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 10 | athgarh
# Error for while looking for information on athgarh at entry 488
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 10 | baturaja
# Processing Record 40 of Set 10 | tommot
# Processing Record 41 of Set 10 | villazon
# Processing Record 42 of Set 10 | nunkini
# Processing Record 43 of Set 10 | san vicente
# Processing Record 44 of Set 10 | tabora
# Processing Record 45 of Set 10 | asekeyevo
# Processing Record 46 of Set 10 | roma
# Processing Record 47 of Set 10 | kourou
# Processing Record 48 of Set 10 | chimbarongo
# Processing Record 49 of Set 10 | palmer
# Processing Record 50 of Set 10 | tabou
# Processing Record 1 of Set 11 | henties bay
# Processing Record 2 of Set 11 | fort-shevchenko
# Processing Record 3 of Set 11 | coos bay
# Processing Record 4 of Set 11 | wanning
# Processing Record 5 of Set 11 | riyadh
# Processing Record 6 of Set 11 | bilibino
# Processing Record 7 of Set 11 | telhara
# Processing Record 8 of Set 11 | almaty
# Processing Record 9 of Set 11 | brits
# Processing Record 10 of Set 11 | kedrovyy
# Processing Record 11 of Set 11 | dromolaxia
# Processing Record 12 of Set 11 | shingu
# Processing Record 13 of Set 11 | polson
# Processing Record 14 of Set 11 | kolosovka
# Processing Record 15 of Set 11 | stromness
# Processing Record 16 of Set 11 | matagami
# Processing Record 17 of Set 11 | ayagoz
# Processing Record 18 of Set 11 | waipawa
# Processing Record 19 of Set 11 | ust-bolsheretsk
# Error for while looking for information on ust-bolsheretsk at entry 519
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 11 | rungata
# Error for while looking for information on rungata at entry 520
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 11 | sao miguel do araguaia
# Processing Record 22 of Set 11 | mecca
# Processing Record 23 of Set 11 | anloga
# Processing Record 24 of Set 11 | altay
# Processing Record 25 of Set 11 | lethem
# Processing Record 26 of Set 11 | sitka
# Processing Record 27 of Set 11 | bur gabo
# Error for while looking for information on bur gabo at entry 527
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 11 | raahe
# Processing Record 29 of Set 11 | itarema
# Processing Record 30 of Set 11 | swan river
# Processing Record 31 of Set 11 | samarai
# Processing Record 32 of Set 11 | beloha
# Processing Record 33 of Set 11 | koroni
# Processing Record 34 of Set 11 | gurun
# Processing Record 35 of Set 11 | llandrindod wells
# Processing Record 36 of Set 11 | mumford
# Processing Record 37 of Set 11 | toccoa
# Processing Record 38 of Set 11 | mutsamudu
# Error for while looking for information on mutsamudu at entry 538
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 11 | kerman
# Processing Record 40 of Set 11 | ronneby
# Processing Record 41 of Set 11 | vila franca do campo
# Processing Record 42 of Set 11 | nabire
# Processing Record 43 of Set 11 | cintalapa
# Processing Record 44 of Set 11 | madras
# Processing Record 45 of Set 11 | fevralsk
# Error for while looking for information on fevralsk at entry 545
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 11 | husavik
# Processing Record 47 of Set 11 | port hedland
# Processing Record 48 of Set 11 | unai
# Processing Record 49 of Set 11 | den helder
# Processing Record 50 of Set 11 | columbus
# Processing Record 1 of Set 12 | zaranj
# Processing Record 2 of Set 12 | bollnas
# Processing Record 3 of Set 12 | boa vista
# Processing Record 4 of Set 12 | ler
# Processing Record 5 of Set 12 | berezovka
# Processing Record 6 of Set 12 | gondar
# Processing Record 7 of Set 12 | beringovskiy
# Processing Record 8 of Set 12 | corrales
# Processing Record 9 of Set 12 | miatli
# Processing Record 10 of Set 12 | sinkat
# Error for while looking for information on sinkat at entry 560
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 12 | sorong
# Processing Record 12 of Set 12 | uglekamensk
# Processing Record 13 of Set 12 | salistea de sus
# Processing Record 14 of Set 12 | eseka
# Processing Record 15 of Set 12 | kamyshlov
# Processing Record 16 of Set 12 | chuguyevka
# Processing Record 17 of Set 12 | pietarsaari
# Processing Record 18 of Set 12 | rietavas
# Processing Record 19 of Set 12 | ussel
# Processing Record 20 of Set 12 | malwan
# Error for while looking for information on malwan at entry 570
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 12 | pangody
# Processing Record 22 of Set 12 | marcona
# Error for while looking for information on marcona at entry 572
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 12 | yazd
# Processing Record 24 of Set 12 | broken hill
# Processing Record 25 of Set 12 | mushie
# Processing Record 26 of Set 12 | preobrazheniye
# Processing Record 27 of Set 12 | sangar
# Processing Record 28 of Set 12 | inderborskiy
# Error for while looking for information on inderborskiy at entry 578
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 12 | hasaki
# Processing Record 30 of Set 12 | sangolqui
# Processing Record 31 of Set 12 | xambioa
# Processing Record 32 of Set 12 | saint-pierre
# Processing Record 33 of Set 12 | senanga
# Processing Record 34 of Set 12 | chudovo
# Processing Record 35 of Set 12 | la palma
# Processing Record 36 of Set 12 | zeya
# Processing Record 37 of Set 12 | raudeberg
# Processing Record 38 of Set 12 | bay city
# Processing Record 39 of Set 12 | yerbogachen
# Processing Record 40 of Set 12 | matamoros
# Processing Record 41 of Set 12 | buariki
# Error for while looking for information on buariki at entry 591
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 12 | ugra
# Processing Record 43 of Set 12 | lishui
# Processing Record 44 of Set 12 | codrington
# Processing Record 45 of Set 12 | rezh
# Processing Record 46 of Set 12 | ambodifototra
# Error for while looking for information on ambodifototra at entry 596
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 12 | mayo
# Processing Record 48 of Set 12 | berdychiv
# Processing Record 49 of Set 12 | kantunilkin
# Processing Record 50 of Set 12 | mahajanga
# Processing Record 1 of Set 13 | igarka
# Processing Record 2 of Set 13 | mandan
# Processing Record 3 of Set 13 | capaci
# Processing Record 4 of Set 13 | baoqing
# Processing Record 5 of Set 13 | liverpool
# Processing Record 6 of Set 13 | tikrit
# Processing Record 7 of Set 13 | north bay
# Processing Record 8 of Set 13 | srirampur
# Processing Record 9 of Set 13 | solnechnyy
# Processing Record 10 of Set 13 | turukhansk
# Processing Record 11 of Set 13 | xining
# Processing Record 12 of Set 13 | mhango
# Processing Record 13 of Set 13 | chiredzi
# Processing Record 14 of Set 13 | san policarpo
# Processing Record 15 of Set 13 | rosarito
# Processing Record 16 of Set 13 | bagaces
# Processing Record 17 of Set 13 | hauterive
# Processing Record 18 of Set 13 | bandundu
# Processing Record 19 of Set 13 | barvinkove
# Processing Record 20 of Set 13 | makungu
# Processing Record 21 of Set 13 | oranjestad
# Processing Record 22 of Set 13 | mumbwa
# Processing Record 23 of Set 13 | huayang
# Processing Record 24 of Set 13 | esmeraldas
# Processing Record 25 of Set 13 | havre
# Processing Record 26 of Set 13 | fomboni
# Processing Record 27 of Set 13 | ust-kuyga
# Processing Record 28 of Set 13 | longkou
# Processing Record 29 of Set 13 | belaya gora
# Processing Record 30 of Set 13 | edd
# Processing Record 31 of Set 13 | kashi
# Processing Record 32 of Set 13 | bumba
# Processing Record 33 of Set 13 | gamba
# Processing Record 34 of Set 13 | luanda
# Processing Record 35 of Set 13 | sant
# Processing Record 36 of Set 13 | ondjiva
# Processing Record 37 of Set 13 | south venice
# Processing Record 38 of Set 13 | mapimi
# Processing Record 39 of Set 13 | slave lake
# Processing Record 40 of Set 13 | mahibadhoo
# Processing Record 41 of Set 13 | medina
# Processing Record 42 of Set 13 | marica
# Processing Record 43 of Set 13 | purranque
# Processing Record 44 of Set 13 | cabedelo
# Processing Record 45 of Set 13 | cochrane
# Processing Record 46 of Set 13 | christchurch
# Processing Record 47 of Set 13 | shimanovsk
# Processing Record 48 of Set 13 | inongo
# Processing Record 49 of Set 13 | bull savanna
# Processing Record 50 of Set 13 | gobabis
# Processing Record 1 of Set 14 | lac du bonnet
# Processing Record 2 of Set 14 | kloulklubed
# Processing Record 3 of Set 14 | findlay
# Processing Record 4 of Set 14 | san quintin
# Processing Record 5 of Set 14 | mingyue
# Processing Record 6 of Set 14 | lucea
# Processing Record 7 of Set 14 | senneterre
# Processing Record 8 of Set 14 | cedral
# Processing Record 9 of Set 14 | buraydah
# Processing Record 10 of Set 14 | flinders
# Processing Record 11 of Set 14 | casino
# Processing Record 12 of Set 14 | naze
# Processing Record 13 of Set 14 | formoso do araguaia
# Error for while looking for information on formoso do araguaia at entry 663
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 14 | ayan
# Processing Record 15 of Set 14 | zhanaozen
# Processing Record 16 of Set 14 | hami
# Processing Record 17 of Set 14 | maningrida
# Processing Record 18 of Set 14 | lar
# Processing Record 19 of Set 14 | vallenar
# Processing Record 20 of Set 14 | cartagena
# Processing Record 21 of Set 14 | serramanna
# Processing Record 22 of Set 14 | praia da vitoria
# Processing Record 23 of Set 14 | santo antonio do ica
# Processing Record 24 of Set 14 | trincomalee
# Processing Record 25 of Set 14 | severo-yeniseyskiy
# Processing Record 26 of Set 14 | capitao poco
# Processing Record 27 of Set 14 | dustlik
# Processing Record 28 of Set 14 | rutul
# Processing Record 29 of Set 14 | longlac
# Error for while looking for information on longlac at entry 679
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 14 | da nang
# Processing Record 31 of Set 14 | baykit
# Processing Record 32 of Set 14 | atasu
# Processing Record 33 of Set 14 | acapulco
# Processing Record 34 of Set 14 | karauzyak
# Error for while looking for information on karauzyak at entry 684
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 14 | pavino
# Processing Record 36 of Set 14 | karratha
# Processing Record 37 of Set 14 | esmeralda
# Processing Record 38 of Set 14 | kalmunai
# Processing Record 39 of Set 14 | saint-augustin
# Processing Record 40 of Set 14 | cobija
# Processing Record 41 of Set 14 | humaita
# Processing Record 42 of Set 14 | dalvik
# Processing Record 43 of Set 14 | san juan de la maguana
# Processing Record 44 of Set 14 | mucurapo
# Processing Record 45 of Set 14 | taltal
# Processing Record 46 of Set 14 | tambun
# Processing Record 47 of Set 14 | hatillo
# Processing Record 48 of Set 14 | college
# Processing Record 49 of Set 14 | astaneh-ye ashrafiyeh
# Processing Record 50 of Set 14 | yumen
# Processing Record 1 of Set 15 | goure
# Processing Record 2 of Set 15 | kota bahru
# Processing Record 3 of Set 15 | azimur
# Error for while looking for information on azimur at entry 703
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 15 | burica
# Error for while looking for information on burica at entry 704
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 15 | nachingwea
# Processing Record 6 of Set 15 | bonthe
# Processing Record 7 of Set 15 | tres arroyos
# Processing Record 8 of Set 15 | alugan
# Processing Record 9 of Set 15 | makakilo city
# Processing Record 10 of Set 15 | lasa
# Processing Record 11 of Set 15 | balkanabat
# Processing Record 12 of Set 15 | caravelas
# Processing Record 13 of Set 15 | yulara
# Processing Record 14 of Set 15 | penzance
# Processing Record 15 of Set 15 | sept-iles
# Processing Record 16 of Set 15 | andros town
# Processing Record 17 of Set 15 | bergen
# Processing Record 18 of Set 15 | lircay
# Processing Record 19 of Set 15 | churapcha
# Processing Record 20 of Set 15 | kavaratti
# Processing Record 21 of Set 15 | sorvag
# Error for while looking for information on sorvag at entry 721
# Received the following error: 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 15 | suntar
# Processing Record 23 of Set 15 | santa elena
# Processing Record 24 of Set 15 | sladna
# Processing Record 25 of Set 15 | floresta
# Processing Record 26 of Set 15 | yeppoon
# Processing Record 27 of Set 15 | srednekolymsk
# Processing Record 28 of Set 15 | platteville
# Processing Record 29 of Set 15 | martos
# Processing Record 30 of Set 15 | skegness
# Processing Record 31 of Set 15 | requena
# Processing Record 32 of Set 15 | masvingo
# Processing Record 33 of Set 15 | zaltan
# Processing Record 34 of Set 15 | richards bay
# Processing Record 35 of Set 15 | polovinnoye
# Processing Record 36 of Set 15 | humberto de campos
# Processing Record 37 of Set 15 | riachao do jacuipe
# Processing Record 38 of Set 15 | gusinoye ozero
# Processing Record 39 of Set 15 | shelburne
# Processing Record 40 of Set 15 | yarim
# Processing Record 41 of Set 15 | minuri
# Processing Record 42 of Set 15 | ornskoldsvik
# Processing Record 43 of Set 15 | maniwaki
# Processing Record 44 of Set 15 | hamilton
# Processing Record 45 of Set 15 | middletown
# ---------------------------------
#     Data Retrieval Complete
# ---------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  punta arenas      CL -53.1500  -70.9167     37.42        93          40
# 1   yellowknife      CA  62.4560 -114.3525     59.56        63          75
# 2        dikson      RU  73.5069   80.5464     42.08        99          99
# 3     manokwari      ID  -0.8667  134.0833     77.94        77         100
# 4        barrow      US  71.2906 -156.7887     34.03        96         100
# 5         wewak      PG  -3.5534  143.6268     79.56        81         100
# 6     cape town      ZA -33.9258   18.4232     68.11        62          20
# 7       mataura      NZ -46.1927  168.8643     43.97        89          93
# 8        lompoc      US  34.6391 -120.4579     60.94        97         100
# 9        hobart      AU -42.8794  147.3294     42.66        85         100
#
#    Wind Speed Current Description
# 0        5.75    scattered clouds
# 1       16.11       broken clouds
# 2        8.05     overcast clouds
# 3        3.62     overcast clouds
# 4       17.18     overcast clouds
# 5        4.18     overcast clouds
# 6       20.71          few clouds
# 7        2.15     overcast clouds
# 8       11.50                mist
# 9        5.75     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
